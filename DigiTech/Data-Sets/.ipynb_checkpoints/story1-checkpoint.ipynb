# %%
#importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
#Loading the dataset
data = pd.read_csv('googlePlayStore.csv')

# %%
# Handle missing values for Rating
data['Rating'] = data['Rating'].fillna(data['Rating'].mean())

# %%
# Handle non-numeric and missing values for Reviews
data['Reviews'] = pd.to_numeric(data['Reviews'], errors='coerce').fillna(0).astype(int)

# %%
# Handle non-numeric values for Installs
# Remove non-numeric entries first
data = data[data['Installs'].str.contains(r'^\d+[,+]?\d*$', na=False)]

# %%
# Remove commas and plus signs, then convert to integers
data['Installs'] = data['Installs'].str.replace('[+,]', '', regex=True).astype(int)

# %%
# Convert categorical variables to dummy/indicator variables
data = pd.get_dummies(data, columns=['Category', 'Type', 'Content Rating', 'Genres'])

# %%
# Display the first few rows of the cleaned dataset to verify changes
data.head()# Handle non-numeric values for Installs
# Out:
#                                                    App    Rating  Reviews  \
# 478                                  Truth or Dare Pro  4.193338        0
# 479    Private Dating, Hide App- Blue for PrivacyHider  4.193338        0
# 480                               Ad Blocker for SayHi  4.193338        4
# 481  AMBW Dating App: Asian Men Black Women Interra...  3.500000        2
# 605             Cardi B Live Stream Video Chat - Prank  4.400000       28
#
#      Size  Installs  Price       Last Updated Current Ver   Android Ver  \
# 478   20M        50  $1.49  September 1, 2017         1.0    4.0 and up
# 479   18k       100  $2.99      July 25, 2017       1.0.1    4.0 and up
# 480  1.2M       100  $3.99     August 2, 2018         1.2  4.0.3 and up
# 481   17M       100  $7.99   January 21, 2017       1.0.1    4.0 and up
# 605  3.4M       500      0      July 16, 2018         2.5  4.0.3 and up
#
#      Category_ART_AND_DESIGN  ...  Genres_Social  Genres_Sports  \
# ...
